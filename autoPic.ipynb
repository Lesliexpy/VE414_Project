# %%
include("./src/autoPic.jl")
# Out:
# WARNING: replacing module dataSplit.
# WARNING: replacing module MyPlot.
# autoClose (generic function with 3 methods)

# %%
pw_far = autoFar("./data_proj_414.csv")
# Out:
# 24094 24094 24094 24094

# %%
plot(pw_far, fmt = :png)
